# %% [markdown]
# <a href="https://colab.research.google.com/github/SVaishnaviVasa/IIITH-AIML-Vaishnavi/blob/main/Copy_of_AIML_Module_4_Lab_3_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 4: Perceptron and Gradient Descent
# ## Lab 3: Gradient Descent
#
# Gradient descent is a very important algorithm to understand, as it underpins many of the more advanced algorithms used in Machine Learning and Deep Learning.
#
# A brief overview of the algorithm is
#
# *   start with a random initialization of the solution.
# *   incrementally change the solution by moving in the direction of negative gradient of the objective function.
# *   repeat the previous step until some convergence criteria is met.
#
# The key equation for change in weight is:
# $$w^{k+1} \leftarrow w^k - \eta \Delta J$$
#
# In this lab, we will discuss stochastic gradient descent, mini-batch gradient descent and batch gradient descent.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %% [markdown]
# # Creating the Data
#
# Let's generate some data with:
# \begin{equation} y_0= 4 \end{equation}
# \begin{equation} y_1= 3 \end{equation}
#
# and also add some noise to the data.

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %% [markdown]
# Let's also plot the data we just created

# %%
plt.plot(X, y, 'b.')
plt.xlabel('x')
plt.ylabel('y', rotation=0)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Cost Function
#
# The equation for calculating cost function is as shown below. The cost function is only for linear regression. For other algorithms, the cost function will be different and the gradients would have to be derived from the cost functions
#
# \begin{equation}
# J(y_{pred}) = \frac{1}{2} m \sum_{i=1}^{m} (h(y_{pred})^{(i)} - y^{(i)})^2
# \end{equation}

# %%
def cal_cost(y_pred, X, y):
    '''
    Calculates the cost for given X and Y.
    y_pred = Vector of y_preds
    X = Row of X's np.zeros((2, j))
    y = Actual y's np.zeros((2, 1))

    where:
        j is the no of features
    '''

    m = len(y)

    predictions = X.dot(y_pred)
    cost = (1 / 2 * m) * np.sum(np.square(predictions - y))

    return cost

# %% [markdown]
# ## Gradients
#
# \begin{equation}
# y_{pred_0}: = y_{pred_0} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}
# \begin{equation}
# y_{pred_1}: = y_{pred_1} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}
# .
#
# .
#
# .
#
# .
#
# \begin{equation}
# y_{pred_j}: = y_{pred_j} -\alpha . (1/m .\sum_{i=1}^{m}(h(y_{pred}^{(i)} - y^{(i)}).X_0^{(i)})
# \end{equation}

# %%
def gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=100):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final y_pred vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    y_pred_history = np.zeros((iterations, 2))

    for it in range(iterations):
        prediction = np.dot(X, y_pred)
        y_pred = y_pred - (1 / m) * learning_rate * (X.T.dot((prediction - y)))
        y_pred_history[it,:] = y_pred.T
        cost_history[it]  = cal_cost(y_pred, X, y)

    return y_pred, cost_history, y_pred_history

# %% [markdown]
# Let's do 1000 iterations with a learning rate of 0.01.
# We will start with a random prediction.

# %%
lr = 0.01
n_iter = 1000

y_pred = np.random.randn(2,1)
X_b = np.c_[np.ones((len(X), 1)), X]
y_pred, cost_history, y_pred_history = gradient_descent(X_b, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 3.903
# y_pred[1]: 3.046
# Final error: 4180.375

# %% [markdown]
# Plotting the error vs Number of iterations

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# Zooming in...

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(range(200), cost_history[:200], 'b.')

# %% [markdown]
# # Stochastic Gradient Descent

# %% [markdown]
# In Batch Gradient Descent we were considering all the examples for every step of Gradient Descent. But what if our dataset is very huge. Deep learning models crave for data. The more the data the more chances of a model to be good. Suppose our dataset has 5 million examples, then just to take one step the model will have to calculate the gradients of all the 5 million examples. This does not seem an efficient way. To tackle this problem we have Stochastic Gradient Descent. In Stochastic Gradient Descent (SGD), we consider just one example at a time to take a single step.

# %%
def stocashtic_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    y_pred = Vector of y_pred np.random.randn(j,1)
    learning_rate
    iterations = no of iterations

    Returns the final y_pred vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)

    for it in range(iterations):
        cost = 0.0

        for i in range(m):
            rand_ind = np.random.randint(0,m)
            X_i = X[rand_ind, :].reshape(1, X.shape[1])
            y_i = y[rand_ind].reshape(1,1)
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate *(X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i)

        cost_history[it]  = cost

    return y_pred, cost_history

# %%
lr = 0.5
n_iter = 50
y_pred = np.random.randn(2, 1)
X_b = np.c_[np.ones((len(X), 1)), X]
y_pred, cost_history = stocashtic_gradient_descent(X_b, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.121
# y_pred[1]: 2.755
# Final error: 41.313

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# # Mini Batch Gradient Descent

# %% [markdown]
# We have seen the Batch Gradient Descent. We have also seen the Stochastic Gradient Descent. Batch Gradient Descent can be used for smoother curves. SGD can be used when the dataset is large. Batch Gradient Descent converges directly to minima. SGD converges faster for larger datasets. But, since in SGD we use only one example at a time, we cannot implement the vectorized implementation on it. This can slow down the computations. To tackle this problem, a mixture of Batch Gradient Descent and SGD is used.
# Neither we use all the dataset all at once nor we use the single example at a time. We use a batch of a fixed number of training examples which is less than the actual dataset and call it a mini-batch. Doing this helps us achieve the advantages of both the former variants we saw.

# %%
def minibatch_gradient_descent(X, y, y_pred, learning_rate=0.01, iterations=10, batch_size=20):
    '''
    X = Matrix of X without added bias units
    y = Vector of Y
    y_pred = Vector of y_preds np.random.randn(j, 1)
    learning_rate
    iterations = no of iterations

    Returns the final theta vector and array of cost history over no of iterations
    '''

    m = len(y)
    cost_history = np.zeros(iterations)
    n_batches = int(m / batch_size)

    for it in range(iterations):
        cost = 0.0
        indices = np.random.permutation(m)
        X = X[indices]
        y = y[indices]

        for i in range(0, m, batch_size):
            X_i = X[i: i + batch_size]
            y_i = y[i: i + batch_size]

            X_i = np.c_[np.ones(len(X_i)), X_i]
            prediction = np.dot(X_i, y_pred)

            y_pred = y_pred - (1 / m) * learning_rate * (X_i.T.dot((prediction - y_i)))
            cost += cal_cost(y_pred, X_i, y_i)

        cost_history[it]  = cost

    return y_pred, cost_history

# %%
lr = 0.1
n_iter = 200
y_pred = np.random.randn(2,1)
y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))
# Out:
# y_pred[0]: 4.148
# y_pred[1]: 2.827
# Final error: 807.488

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# Things to try out:
#
# 1. Change batch size in mini-batch gradient descent.
# 2. Test all the three out on real datasets.
# 3. Compare the effects of changing learning rate by the same amount in Batch GD, SGD and Mini-batch GD.

# %% [markdown]
# ---
#
#
#
# **Change batch size in mini-batch gradient descent.**

# %%
lr = 0.1
n_iter = 200
batch_size_new = 500
y_pred = np.random.randn(2, 1)
y_pred, cost_history = minibatch_gradient_descent(X, y, y_pred, lr, n_iter, batch_size_new)

print('y_pred[0]: {:0.3f}\ny_pred[1]: {:0.3f}'.format(y_pred[0][0], y_pred[1][0]))
print('Final error: {:0.3f}'.format(cost_history[-1]))

fig, ax = plt.subplots(figsize=(10, 8))
ax.set_ylabel('Error')
ax.set_xlabel('Number of iterations')
y_pred = np.random.randn(2, 1)
ax.plot(range(n_iter), cost_history, 'b.')
plt.show()
# Out:
# y_pred[0]: 4.151
# y_pred[1]: 2.827
# Final error: 4039.090

# %% [markdown]
# ---
#
# **Test all the three out on real datasets.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler

# breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

learning_rates = [0.001, 0.01, 0.1, 0.5]

n_iter = 200

# Batch Gradient Descent
def batch_gradient_descent(X, y, learning_rate, iterations):
    m, n = X.shape
    weights = np.random.randn(n + 1, 1)
    X_bias = np.c_[np.ones(m), X]

    for _ in range(iterations):
        gradient = (1 / m) * X_bias.T.dot(X_bias.dot(weights) - y)
        weights = weights - learning_rate * gradient

    return weights

# Stochastic Gradient Descent
def stochastic_gradient_descent(X, y, learning_rate, iterations):
    m, n = X.shape
    weights = np.random.randn(n + 1, 1)
    X_bias = np.c_[np.ones(m), X]

    for _ in range(iterations):
        for i in range(m):
            random_index = np.random.randint(m)
            xi = X_bias[random_index:random_index+1]
            yi = y[random_index:random_index+1]
            gradient = xi.T.dot(xi.dot(weights) - yi)
            weights = weights - learning_rate * gradient

    return weights

# Mini-Batch Gradient Descent
def minibatch_gradient_descent(X, y, learning_rate, iterations, batch_size):
    m, n = X.shape
    weights = np.random.randn(n + 1, 1)
    X_bias = np.c_[np.ones(m), X]
    n_batches = int(m / batch_size)

    for _ in range(iterations):
        indices = np.random.permutation(m)
        X_bias = X_bias[indices]
        y = y[indices]

        for i in range(0, m, batch_size):
            X_i = X_bias[i:i+batch_size]
            y_i = y[i:i+batch_size]

            gradient = (2 / batch_size) * X_i.T.dot(X_i.dot(weights) - y_i)
            weights = weights - learning_rate * gradient

    return weights

#For different learning rates
for lr in learning_rates:
    weights_batch = batch_gradient_descent(X_scaled, y.reshape(-1, 1), lr, n_iter)
    weights_stochastic = stochastic_gradient_descent(X_scaled, y.reshape(-1, 1), lr, n_iter)
    batch_size = 20
    weights_minibatch = minibatch_gradient_descent(X_scaled, y.reshape(-1, 1), lr, n_iter, batch_size)

    _, cost_history_batch = batch_gradient_descent_with_cost_history(X_scaled, y.reshape(-1, 1), lr, n_iter)
    _, cost_history_stochastic = stochastic_gradient_descent_with_cost_history(X_scaled, y.reshape(-1, 1), lr, n_iter)
    _, cost_history_minibatch = minibatch_gradient_descent_with_cost_history(X_scaled, y.reshape(-1, 1), lr, n_iter, batch_size)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 3, 1)
    plt.plot(range(len(cost_history_batch)), cost_history_batch, label='Batch GD')
    plt.title(f'Batch Gradient Descent (LR={lr})')
    plt.xlabel('Number of Iterations')
    plt.ylabel('Cost')
    plt.legend()

    plt.subplot(1, 3, 2)
    plt.plot(range(len(cost_history_stochastic)), cost_history_stochastic, label='Stochastic GD')
    plt.title(f'Stochastic Gradient Descent (LR={lr})')
    plt.xlabel('Number of Iterations')
    plt.ylabel('Cost')
    plt.legend()

    plt.subplot(1, 3, 3)
    plt.plot(range(len(cost_history_minibatch)), cost_history_minibatch, label='Mini-Batch GD')
    plt.title(f'Mini-Batch Gradient Descent (LR={lr})')
    plt.xlabel('Number of Iterations')
    plt.ylabel('Cost')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-36-ee339be47580>:42: RuntimeWarning: invalid value encountered in subtract
#   weights = weights - learning_rate * gradient
# <ipython-input-35-c7914a373556>:48: RuntimeWarning: overflow encountered in square
#   cost = np.sum((X_bias.dot(weights) - y) ** 2) / (2 * m)
# <ipython-input-35-c7914a373556>:45: RuntimeWarning: invalid value encountered in subtract
#   weights = weights - learning_rate * gradient
# <ipython-input-35-c7914a373556>:80: RuntimeWarning: overflow encountered in square
#   cost = np.sum((X_bias.dot(weights) - y) ** 2) / (2 * m)

# %%
def plot_cost_history(cost_history, method):
    plt.plot(range(len(cost_history)), cost_history, label=method)
    plt.xlabel('Number of Iterations')
    plt.ylabel('Cost')
    plt.title('Cost Convergence')
    plt.legend()
    plt.show()

def batch_gradient_descent_with_cost_history(X, y, learning_rate, iterations):
    m, n = X.shape
    weights = np.random.randn(n + 1, 1)
    X_bias = np.c_[np.ones(m), X]
    cost_history = []

    for _ in range(iterations):
        gradient = (1 / m) * X_bias.T.dot(X_bias.dot(weights) - y)
        weights = weights - learning_rate * gradient

        cost = np.sum((X_bias.dot(weights) - y) ** 2) / (2 * m)
        cost_history.append(cost)

    return weights, cost_history

weights_batch, cost_history_batch = batch_gradient_descent_with_cost_history(X_scaled, y.reshape(-1, 1), lr, n_iter)

plot_cost_history(cost_history_batch, 'Batch Gradient Descent')

def stochastic_gradient_descent_with_cost_history(X, y, learning_rate, iterations):
    m, n = X.shape
    weights = np.random.randn(n + 1, 1)
    X_bias = np.c_[np.ones(m), X]
    cost_history = []

    for _ in range(iterations):
        for i in range(m):
            random_index = np.random.randint(m)
            xi = X_bias[random_index:random_index+1]
            yi = y[random_index:random_index+1]
            gradient = xi.T.dot(xi.dot(weights) - yi)
            weights = weights - learning_rate * gradient

        cost = np.sum((X_bias.dot(weights) - y) ** 2) / (2 * m)
        cost_history.append(cost)

    return weights, cost_history

weights_stochastic, cost_history_stochastic = stochastic_gradient_descent_with_cost_history(X_scaled, y.reshape(-1, 1), lr, n_iter)

plot_cost_history(cost_history_stochastic, 'Stochastic Gradient Descent')

def minibatch_gradient_descent_with_cost_history(X, y, learning_rate, iterations, batch_size):
    m, n = X.shape
    weights = np.random.randn(n + 1, 1)
    X_bias = np.c_[np.ones(m), X]
    n_batches = int(m / batch_size)
    cost_history = []

    for _ in range(iterations):
        indices = np.random.permutation(m)
        X_bias = X_bias[indices]
        y = y[indices]

        for i in range(0, m, batch_size):
            X_i = X_bias[i:i+batch_size]
            y_i = y[i:i+batch_size]

            gradient = (2 / batch_size) * X_i.T.dot(X_i.dot(weights) - y_i)
            weights = weights - learning_rate * gradient

        cost = np.sum((X_bias.dot(weights) - y) ** 2) / (2 * m)
        cost_history.append(cost)

    return weights, cost_history

weights_minibatch, cost_history_minibatch = minibatch_gradient_descent_with_cost_history(X_scaled, y.reshape(-1, 1), lr, n_iter, batch_size)

plot_cost_history(cost_history_minibatch, 'Mini-Batch Gradient Descent')
# Out:
# <ipython-input-37-e6bf66cc3a79>:42: RuntimeWarning: overflow encountered in square
#   cost = np.sum((X_bias.dot(weights) - y) ** 2) / (2 * m)
# <ipython-input-37-e6bf66cc3a79>:40: RuntimeWarning: invalid value encountered in subtract
#   weights = weights - learning_rate * gradient
# <ipython-input-37-e6bf66cc3a79>:70: RuntimeWarning: overflow encountered in square
#   cost = np.sum((X_bias.dot(weights) - y) ** 2) / (2 * m)

# %% [markdown]
# ---
#
# **Compare the effects of changing learning rate by the same amount in Batch GD, SGD and Mini-batch GD.**

# %% [markdown]
# 1. **Batch Gradient Descent (BGD):**
#    - Lower learning rates (0.001 and 0.01) converge slowly.
#    - Moderate learning rate (0.1) appears to converge efficiently.
#    - Higher learning rate (0.5) diverges, indicating overshooting.
#
# 2. **Stochastic Gradient Descent (SGD):**
#    - Lower learning rates (0.001 and 0.01) exhibit slow and noisy convergence.
#    - Moderate learning rate (0.1) shows more stability and reasonable convergence.
#    - Higher learning rate (0.5) converges faster, but with more oscillations.
#
# 3. **Mini-Batch Gradient Descent (MBGD):**
#    - Similar trends to SGD with lower learning rates converging slowly and higher rates showing more oscillations.
#    - Moderate learning rate (0.1) demonstrates a balance between convergence speed and stability.
#    - Higher learning rate (0.5) leads to oscillations, but less severe than in SGD.
